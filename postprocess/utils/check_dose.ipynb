# %%
import ants
import matplotlib.pyplot as plt

# %%
dose = ants.image_read("../cache/caowujun_t0_boron.nii")
img = ants.image_read("/home/zhaosheng/calc/topas/niis/caowujun_t0.nii")
dose = dose.numpy()
ct = img.numpy()

# %%
plt.imshow(dose[:,:,10])

# %%
plt.imshow(ct[:,:,10])
